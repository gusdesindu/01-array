# %% [markdown]
# <a href="https://colab.research.google.com/github/gusdesindu/01-array/blob/main/Soal_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Membuat array untuk menyimpan nilai

# %%
data_nilai = []

# %% [markdown]
# Program untuk memasukkan nilai

# %%
for i in range(10):
    angka = int(input(f"Input nilai ke-{i+1}: "))
    data_nilai.append(angka)
# Out:
# Input nilai ke-1: 60
# Input nilai ke-2: 55
# Input nilai ke-3: 45
# Input nilai ke-4: 70
# Input nilai ke-5: 75
# Input nilai ke-6: 90
# Input nilai ke-7: 70
# Input nilai ke-8: 85
# Input nilai ke-9: 80
# Input nilai ke-10: 100

# %% [markdown]
# Menghitung jumlah mahasiswa yang lulus

# %%
jumlah_lulus = 0
for x in data_nilai:
    if x >= 60:
        jumlah_lulus += 1

# %% [markdown]
# Menampilkan hasil

# %%
print("===== HASIL PERHITUNGAN =====")
print("Data Nilai        :", data_nilai)
print("Nilai Maksimum    :", max(data_nilai))
print("Nilai Minimum     :", min(data_nilai))
print("Rata-rata Nilai   :", sum(data_nilai)/len(data_nilai))
print("Total Lulus       :", jumlah_lulus)
print("Total Tidak Lulus :", len(data_nilai) - jumlah_lulus)
# Out:
# ===== HASIL PERHITUNGAN =====
# Data Nilai        : [60, 55, 45, 70, 75, 90, 70, 85, 80, 100]
# Nilai Maksimum    : 100
# Nilai Minimum     : 45
# Rata-rata Nilai   : 73.0
# Total Lulus       : 8
# Total Tidak Lulus : 2

# %% [markdown]
# Grafik Perbandingan Nilai

# %%
import matplotlib.pyplot as plt

label_grafik = ["Nilai Tertinggi", "Nilai Terendah"]
data_grafik = [nilai_tertinggi, nilai_terendah]

plt.bar(label_grafik, data_grafik)
plt.title("Grafik Perbandingan Nilai")
plt.ylabel("Nilai")
plt.show()

# %% [markdown]
# Grafik Persentase Kelulusan

# %%
label_pie = ["Lulus", "Tidak Lulus"]
data_pie = [jumlah_lulus, jumlah_tidak_lulus]

plt.pie(data_pie, labels=label_pie, autopct='%1.1f%%')
plt.title("Grafik Persentase Kelulusan")
plt.axis('equal')
plt.show()
